# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
pip install geoviews
# Out:
# Requirement already satisfied: geoviews in /opt/homebrew/anaconda3/lib/python3.11/site-packages (1.10.1)
# Requirement already satisfied: bokeh<3.3.0,>=3.1.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from geoviews) (3.2.1)
# Requirement already satisfied: cartopy>=0.18.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from geoviews) (0.22.0)
# Requirement already satisfied: holoviews>=1.16.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from geoviews) (1.17.1)
# Requirement already satisfied: packaging in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from geoviews) (23.1)
# Requirement already satisfied: numpy in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from geoviews) (1.24.3)
# Requirement already satisfied: shapely in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from geoviews) (2.0.1)
# Requirement already satisfied: param in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from geoviews) (1.13.0)
# Requirement already satisfied: panel>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from geoviews) (1.2.1)
# Requirement already satisfied: pyproj in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: xyzservices in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: Jinja2>=2.9 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (1.0.5)
# Requirement already satisfied: pandas>=1.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (2.0.3)
# Requirement already satisfied: pillow>=7.1.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.0)
# Requirement already satisfied: tornado>=5.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.3.2)
# Requirement already satisfied: matplotlib>=3.4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from cartopy>=0.18.0->geoviews) (3.7.2)
# Requirement already satisfied: pyshp>=2.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from holoviews>=1.16.0->geoviews) (2.3.0)
# Requirement already satisfied: colorcet in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: markdown in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: linkify-it-py in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (4.65.0)
# Requirement already satisfied: bleach in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: typing-extensions in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (4.7.1)
# Requirement already satisfied: certifi in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pyproj->geoviews) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh<3.3.0,>=3.1.0->geoviews) (2.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas>=1.2->bokeh<3.3.0,>=3.1.0->geoviews) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas>=1.2->bokeh<3.3.0,>=3.1.0->geoviews) (2023.3)
# Requirement already satisfied: six>=1.9.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.5.0)
# Requirement already satisfied: uc-micro-py in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->panel>=1.0.0->geoviews) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->panel>=1.0.0->geoviews) (1.26.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import geoviews as gv
# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("Output data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0           tiksi  71.6872  128.8694    269.60        86         100
# 1        1        cidreira -30.1811  -50.2056    294.10        82          98
# 2        2        lycksele  64.5954   18.6735    279.50       100         100
# 3        3  ribeira grande  38.5167  -28.7000    296.37        94          40
# 4        4     nova sintra  14.8667  -24.7167    298.26        69          91
#
#    Wind Speed Country        Date
# 0        1.47      RU  1696439051
# 1        4.29      BR  1696439051
# 2        0.00      SE  1696439052
# 3        4.92      PT  1696439052
# 4        0.95      CV  1696439052

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
#https://hvplot.holoviz.org/user_guide/Geographic_Data.html
map_plot = city_data_df.hvplot.points('Lng',
                                    'Lat',
                                    geo=True,
                                    size='Humidity',
                                    scale=1,
                                    color='City',
                                    tiles='OSM',
                                    )

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Define your criteria for ideal weather conditions in Fahrenheit
temp_range = (city_data_df["Max Temp"] >= 250) & (city_data_df["Max Temp"] <= 350)
humidity_range = (city_data_df["Humidity"] >= 20) & (city_data_df["Humidity"] <= 50) 
wind_threshold = city_data_df["Wind Speed"] <= 15
cloudiness_threshold = city_data_df["Cloudiness"] <= 30


# Apply the conditions to filter the DataFrame
ideal_df = city_data_df[temp_range & humidity_range & wind_threshold & cloudiness_threshold].copy()

# Drop any rows with null values if necessary
ideal_df.dropna(inplace=True)

# Display sample data
ideal_df.head()
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 30        30  ad diwaniyah  31.9905   44.9306    302.20        36          29
# 86        86        corona  33.8753 -117.5664    303.82        38           0
# 126      126     los andes -32.8337  -70.5983    291.49        35           0
# 130      130         qa'en  33.7265   59.1844    295.25        32           4
# 154      154     lewisburg  35.4492  -86.7889    301.57        47           0
#
#      Wind Speed Country        Date
# 30         8.44      IQ  1696439056
# 86         8.05      US  1696439067
# 126        2.27      CL  1696438812
# 130        1.70      IR  1696439085
# 154        4.12      US  1696439090

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 30   ad diwaniyah      IQ  31.9905   44.9306        36
# 86         corona      US  33.8753 -117.5664        38
# 126     los andes      CL -32.8337  -70.5983        35
# 130         qa'en      IR  33.7265   59.1844        32
# 154     lewisburg      US  35.4492  -86.7889        47

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# url = f"https://api.geoapify.com/v2/places?categories=accommodation.hotel&filter=circle:-74.0054261,40.7135482,10000&bias=proximity:-74.0054261,40.7135482&limit=20&apiKey={geoapify_key}"
         
# response = requests.get(url)
# data = response.json()
# data['features'][0]['properties']['name']


# lng = 75.8106
# lat = 41.1702
# base_url_trial = "https://api.geoapify.com/v2/places?"
# radius = 10000
# params_trial = {'categories': 'accommodation.hotel',
#                'filter': f'circle:{lng},{lat},{radius}',
#                 'bias': f'proximity:{lng},{lat}',
#                 'apiKey':geoapify_key
#                }
# response = requests.get(base_url_trial, params_trial).json()

# %%
# Set parameters to search for a hotel
radius = 10000
params = {'categories': "accommodation.hotel",
          'apiKey': geoapify_key,
         }

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places?"


    # Make and API request using the params dictionaty
    response = requests.get(base_url, params)
    
    # Convert the API response to JSON format
    name_address = response.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# ad diwaniyah - nearest hotel: فندق ومطعم الديوانية
# corona - nearest hotel: Best Western Corona
# los andes - nearest hotel: Hotel Gloria
# qa'en - nearest hotel: No hotel found
# lewisburg - nearest hotel: No hotel found
# samdari - nearest hotel: No hotel found
# hassi messaoud - nearest hotel: AMC
# mount isa - nearest hotel: Ibis Styles
# rio gallegos - nearest hotel: Amérian Río Gallegos Apart & Suites
# kaimganj - nearest hotel: No hotel found
# sanliurfa - nearest hotel: DoubleTree by Hilton Sanliurfa
# tagta - nearest hotel: No hotel found
# luwingu - nearest hotel: No hotel found
# erenhot - nearest hotel: Oulen hotel
# kulgam - nearest hotel: No hotel found
# puerto deseado - nearest hotel: Los Olmos
# saynshand - nearest hotel: No hotel found
# zaragoza - nearest hotel: Hotel Pilar Plaza
# queimadas - nearest hotel: No hotel found
# raton - nearest hotel: Travelodge
# gillette - nearest hotel: Montgomery Hotel
# catriel - nearest hotel: Stelliato
# barberton - nearest hotel: No hotel found
# ghat - nearest hotel: فندق تاسيلي
# firuzabad - nearest hotel: هتل جهانگردی
# najaf - nearest hotel: مديرية مجاري النجف
# zhangjiakou - nearest hotel: 商务宾馆
# alice springs - nearest hotel: Aurora Alice Springs
# bayanhongor - nearest hotel: No hotel found
# sume - nearest hotel: No hotel found
# baicheng - nearest hotel: 白城鶴翔大酒店
# azare - nearest hotel: No hotel found
# 'ain el melh - nearest hotel: No hotel found
# sabha - nearest hotel: فندق الكاظم-سبها
# chokwe - nearest hotel: Limpopo Hotel
# badiyah - nearest hotel: Al Areen Hotel Apartments
# kotkapura - nearest hotel: Hotel Shahi Haveli
# dzhalagash - nearest hotel: No hotel found
#                City Country      Lat       Lng  Humidity  \
# 30     ad diwaniyah      IQ  31.9905   44.9306        36
# 86           corona      US  33.8753 -117.5664        38
# 126       los andes      CL -32.8337  -70.5983        35
# 130           qa'en      IR  33.7265   59.1844        32
# 154       lewisburg      US  35.4492  -86.7889        47
# 163         samdari      IN  25.8167   72.5833        38
# 170  hassi messaoud      DZ  31.6804    6.0729        26
# 172       mount isa      AU -20.7333  139.5000        22
# 184    rio gallegos      AR -51.6226  -69.2181        33
# 209        kaimganj      IN  27.5667   79.3500        49
# 210       sanliurfa      TR  37.2128   38.7817        31
# 219           tagta      TM  41.6504   59.9164        40
# 236         luwingu      ZM -10.2621   29.9271        26
# 240         erenhot      CN  43.6475  111.9767        26
# 260          kulgam      IN  33.6500   75.0167        42
# 280  puerto deseado      AR -47.7503  -65.8938        39
# 293       saynshand      MN  44.8824  110.1163        28
# 295        zaragoza      ES  41.6561   -0.8773        38
# 310       queimadas      BR -10.9783  -39.6264        23
# 311           raton      US  36.9034 -104.4391        39
# 319        gillette      US  44.2911 -105.5022        50
# 327         catriel      AR -37.8791  -67.7956        23
# 328       barberton      ZA -25.7884   31.0532        36
# 336            ghat      LY  24.9647   10.1728        34
# 349       firuzabad      IR  28.8438   52.5707        21
# 354           najaf      IQ  31.9985   44.3398        34
# 386     zhangjiakou      CN  40.8100  114.8794        31
# 393   alice springs      AU -23.7000  133.8833        34
# 402     bayanhongor      MN  46.7167  100.1167        47
# 413            sume      BR  -7.6717  -36.8800        23
# 415        baicheng      CN  45.6167  122.8167        38
# 420           azare      NG  11.6765   10.1948        29
# 441    'ain el melh      DZ  34.8415    4.1638        30
# 443           sabha      LY  27.0377   14.4283        26
# 484          chokwe      MZ -24.5333   32.9833        44
# 555         badiyah      OM  22.4500   58.8000        38
# 561       kotkapura      IN  30.5819   74.8330        20
# 563      dzhalagash      KZ  45.0833   64.6667        37
#
#                               Hotel Name
# 30                  فندق ومطعم الديوانية
# 86                   Best Western Corona
# 126                         Hotel Gloria
# 130                       No hotel found
# 154                       No hotel found
# 163                       No hotel found
# 170                                  AMC
# 172                          Ibis Styles
# 184  Amérian Río Gallegos Apart & Suites
# 209                       No hotel found
# 210       DoubleTree by Hilton Sanliurfa
# 219                       No hotel found
# 236                       No hotel found
# 240                          Oulen hotel
# 260                       No hotel found
# 280                            Los Olmos
# 293                       No hotel found
# 295                    Hotel Pilar Plaza
# 310                       No hotel found
# 311                           Travelodge
# 319                     Montgomery Hotel
# 327                            Stelliato
# 328                       No hotel found
# 336                          فندق تاسيلي
# 349                         هتل جهانگردی
# 354                   مديرية مجاري النجف
# 386                                 商务宾馆
# 393                 Aurora Alice Springs
# 402                       No hotel found
# 413                       No hotel found
# 415                              白城鶴翔大酒店
# 420                       No hotel found
# 441                       No hotel found
# 443                     فندق الكاظم-سبها
# 484                        Limpopo Hotel
# 555            Al Areen Hotel Apartments
# 561                   Hotel Shahi Haveli
# 563                       No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot for the hotels
hotels_plot = hotel_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    tiles = "OSM",
    hover_cols=list(hotel_df.columns)
    
)

# Display the map
hotels_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
